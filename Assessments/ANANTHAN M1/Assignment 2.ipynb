# %% [markdown]
# # Data Visualization and Pre-processing

# %% [markdown]
# Perform Below Tasks to complete the assignment:-

# %% [markdown]
# # Tasks

# %% [markdown]
# # 1. Download the dataset:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# # 2. Load the dataset.

# %%
data = pd.read_csv(r"C:\Users\ANANTH\Documents\IBM\Churn_Modelling.csv")

# %%
print(data.head())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
print(data.tail())
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# # 3. Perform Below Visualizations

# %% [markdown]
# # i.Univariate Analysis

# %%
print(sns.distplot(data['Age']))
# Out:
# C:\Users\ANANTH\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.boxplot(data['Age']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # ii.Bi - Variate Analysis

# %%
print(sns.lineplot(data['CreditScore'], data['Age']))
# Out:
# C:\Users\ANANTH\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
plt.figure(figsize=(50,50))
print(sns.barplot(data['NumOfProducts'], data['IsActiveMember']))
# Out:
# C:\Users\ANANTH\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.scatterplot(data['NumOfProducts'], data['Balance']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # iii.Multi - Variate Analysis

# %%
print(sns.scatterplot(data['Age'], data['Tenure'], hue = data['Gender']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.pairplot(data))

# %%
print(data.corr())
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.figure(figsize=(10,8))
print(sns.heatmap(data.corr(), annot = True))
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %% [markdown]
# # 4.Descriptive statistics

# %%
print(data.mean())
# Out:
# RowNumber          5.000500e+03
# CustomerId         1.569094e+07
# Surname            0.000000e+00
# CreditScore        0.000000e+00
# Geography          0.000000e+00
# Gender             0.000000e+00
# Age                0.000000e+00
# Tenure             0.000000e+00
# Balance            7.648589e+04
# NumOfProducts      1.530200e+00
# HasCrCard          7.055000e-01
# IsActiveMember     5.151000e-01
# EstimatedSalary    1.000902e+05
# Exited             2.037000e-01
# dtype: float64

# %%
print(data.median())
# Out:
# RowNumber          5.000500e+03
# CustomerId         1.569074e+07
# CreditScore        6.520000e+02
# Age                3.700000e+01
# Tenure             5.000000e+00
# Balance            9.719854e+04
# NumOfProducts      1.000000e+00
# HasCrCard          1.000000e+00
# IsActiveMember     1.000000e+00
# EstimatedSalary    1.001939e+05
# Exited             0.000000e+00
# dtype: float64

# %%
print(data.mode())
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender   Age  \
# 0             1    15565701   Smith        850.0    France   Male  37.0
# 1             2    15565706     NaN          NaN       NaN    NaN   NaN
# 2             3    15565714     NaN          NaN       NaN    NaN   NaN
# 3             4    15565779     NaN          NaN       NaN    NaN   NaN
# 4             5    15565796     NaN          NaN       NaN    NaN   NaN
# 5             6    15565806     NaN          NaN       NaN    NaN   NaN
# 6             7    15565878     NaN          NaN       NaN    NaN   NaN
# 7             8    15565879     NaN          NaN       NaN    NaN   NaN
# 8             9    15565891     NaN          NaN       NaN    NaN   NaN
# 9            10    15565996     NaN          NaN       NaN    NaN   NaN
# 10           11    15566030     NaN          NaN       NaN    NaN   NaN
# 11           12    15566091     NaN          NaN       NaN    NaN   NaN
# ...

# %%
print(data.var())
# Out:
# RowNumber          8.334167e+06
# CustomerId         5.174815e+09
# CreditScore        9.341860e+03
# Age                1.099941e+02
# Tenure             8.364673e+00
# Balance            3.893436e+09
# NumOfProducts      3.383218e-01
# HasCrCard          2.077905e-01
# IsActiveMember     2.497970e-01
# EstimatedSalary    3.307457e+09
# Exited             1.622225e-01
# dtype: float64

# %%
print(data.std())
# Out:
# RowNumber           2886.895680
# CustomerId         71936.186123
# CreditScore           96.653299
# Age                   10.487806
# Tenure                 2.892174
# Balance            62397.405202
# NumOfProducts          0.581654
# HasCrCard              0.455840
# IsActiveMember         0.499797
# EstimatedSalary    57510.492818
# Exited                 0.402769
# dtype: float64

# %%
print(data.describe())
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
print(data['Age'].unique())
# Out:
# [42 41 39 43 44 50 29 27 31 24 34 25 35 45 58 32 38 46 36 33 40 51 61 49
#  37 19 66 56 26 21 55 75 22 30 28 65 48 52 57 73 47 54 72 20 67 79 62 53
#  80 59 68 23 60 70 63 64 18 82 69 74 71 76 77 88 85 84 78 81 92 83]

# %%
print(data['Gender'].unique())
# Out:
# ['Female' 'Male']

# %%
print(data['Age'].value_counts())
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
# 33    442
# 40    432
# 39    423
# 32    418
# 31    404
# 41    366
# 29    348
# 30    327
# 42    321
# 43    297
# 28    273
# 44    257
# 45    229
# 46    226
# 27    209
# 26    200
# 47    175
# 48    168
# 25    154
# 49    147
# 50    134
# 24    132
# 51    119
# 52    102
# 23     99
#      ...
# 21     53
# 62     52
# 63     40
# 20     40
# 67     37
# 64     37
# 66     35
# 19     27
# 71     27
# 69     22
# 18     22
# 72     21
# 68     19
# 74     18
# 70     18
# 65     18
# 73     13
# 76     11
# 77     10
# 75      9
# 78      5
# 79      4
# 81      4
# 80      3
# 84      2
# 92      2
# 88      1
# 82      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %% [markdown]
# #  5.Handle the Missing values

# %%
print(data.isnull().any())
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
print(data.isnull().sum())
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # 6.Outliers

# %%
print(sns.boxplot(data['Balance']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
q  = data.quantile([0.75,0.25])

# %%
print(q)
# Out:
#       RowNumber   CustomerId  CreditScore  Gender   Age  Tenure  Balance  \
# 0.75    7500.25  15753233.75        718.0     1.0  44.0     7.0     10.0
# 0.25    2500.75  15628528.25        584.0     0.0  32.0     3.0      0.0
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0.75            1.0        1.0             1.0      149388.2475     0.0
# 0.25            0.0        0.0             0.0       51002.1100     0.0

# %%
iqr =  q.iloc[0] - q.iloc[1]

# %%
print(iqr)
# Out:
# RowNumber            4999.5000
# CustomerId         124705.5000
# CreditScore           134.0000
# Gender                  1.0000
# Age                    12.0000
# Tenure                  4.0000
# Balance                10.0000
# NumOfProducts           1.0000
# HasCrCard               1.0000
# IsActiveMember          1.0000
# EstimatedSalary     98386.1375
# Exited                  0.0000
# dtype: float64

# %%
u = q.iloc[0] + (1.5*iqr)

# %%
print(u)
# Out:
# RowNumber          1.499950e+04
# CustomerId         1.594029e+07
# CreditScore        9.190000e+02
# Gender             2.500000e+00
# Age                6.200000e+01
# Tenure             1.300000e+01
# Balance            2.500000e+01
# NumOfProducts      2.500000e+00
# HasCrCard          2.500000e+00
# IsActiveMember     2.500000e+00
# EstimatedSalary    2.969675e+05
# Exited             0.000000e+00
# dtype: float64

# %%
l = q.iloc[1] - (1.5*iqr)

# %%
print(l)
# Out:
# RowNumber         -4.998500e+03
# CustomerId         1.544147e+07
# CreditScore        3.830000e+02
# Gender            -1.500000e+00
# Age                1.400000e+01
# Tenure            -3.000000e+00
# Balance           -1.500000e+01
# NumOfProducts     -1.500000e+00
# HasCrCard         -1.500000e+00
# IsActiveMember    -1.500000e+00
# EstimatedSalary   -9.657710e+04
# Exited             0.000000e+00
# dtype: float64

# %%
data['Balance'] = np.where(data['Balance']>45, 31, data['Balance'])

# %%
print(sns.boxplot(data['Balance']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # 7.Encoding

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
le = LabelEncoder()
oneh = OneHotEncoder()
data['Gender'] = le.fit_transform(data['Gender'])

# %%
print(data.head())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0   42
# 1          2    15647311      Hill          608     Spain       0   41
# 2          3    15619304      Onio          502    France       0   42
# 3          4    15701354      Boni          699    France       0   39
# 4          5    15737888  Mitchell          850     Spain       0   43
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2      0.0              1          1               1        101348.88
# 1       1     10.0              1          0               1        112542.58
# 2       8     10.0              3          1               0        113931.57
# 3       1      0.0              2          0               0         93826.63
# 4       2     10.0              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
data['NumOfProducts'] = le.fit_transform(data['NumOfProducts'])
data['HasCrCard'] = le.fit_transform(data['HasCrCard'])

# %%
print(data.head())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0   42
# 1          2    15647311      Hill          608     Spain       0   41
# 2          3    15619304      Onio          502    France       0   42
# 3          4    15701354      Boni          699    France       0   39
# 4          5    15737888  Mitchell          850     Spain       0   43
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2      0.0              0          1               1        101348.88
# 1       1     10.0              0          0               1        112542.58
# 2       8     10.0              2          1               0        113931.57
# 3       1      0.0              1          0               0         93826.63
# 4       2     10.0              0          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# # 8.Split the data into dependent and independent variables

# %% [markdown]
# # 1.independent values

# %%
x = data.iloc[:, 0:6]

# %%
print(x) #independent values
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender
# 0             1    15634602        Hargrave          619    France       0
# 1             2    15647311            Hill          608     Spain       0
# 2             3    15619304            Onio          502    France       0
# 3             4    15701354            Boni          699    France       0
# 4             5    15737888        Mitchell          850     Spain       0
# 5             6    15574012             Chu          645     Spain       1
# 6             7    15592531        Bartlett          822    France       1
# 7             8    15656148          Obinna          376   Germany       0
# 8             9    15792365              He          501    France       1
# 9            10    15592389              H?          684    France       1
# 10           11    15767821          Bearce          528    France       1
# ...

# %% [markdown]
# # 2.dependent values

# %%
y = data['EstimatedSalary']

# %%
print(y) #dependent values
# Out:
# 0       101348.88
# 1       112542.58
# 2       113931.57
# 3        93826.63
# 4        79084.10
# 5       149756.71
# 6        10062.80
# 7       119346.88
# 8        74940.50
# 9        71725.73
# 10       80181.12
# 11       76390.01
# 12       26260.98
# 13      190857.79
# 14       65951.65
# 15       64327.26
# 16        5097.67
# 17       14406.41
# 18      158684.81
# 19       54724.03
# 20      170886.17
# 21      138555.46
# 22      118913.53
# 23        8487.75
# 24      187616.16
# 25      124508.29
# 26      170041.95
# 27       38433.35
# 28      100187.43
# 29       53483.21
#           ...
# 9970    119377.36
# 9971    166472.81
# 9972    171552.02
# 9973    157474.10
# 9974     13549.24
# 9975    196526.55
# 9976     84419.78
# 9977     24991.92
# 9978    191608.97
# 9979      2988.28
# 9980     99595.67
# 9981     53445.17
# 9982    115146.40
# 9983    151325.24
# 9984     51695.41
# 9985     96833.00
# 9986     34047.54
# 9987      1914.41
# 9988     49337.84
# ...

# %% [markdown]
# # 9.Scaling

# %%
print(x)
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender
# 0             1    15634602        Hargrave          619    France       0
# 1             2    15647311            Hill          608     Spain       0
# 2             3    15619304            Onio          502    France       0
# 3             4    15701354            Boni          699    France       0
# 4             5    15737888        Mitchell          850     Spain       0
# 5             6    15574012             Chu          645     Spain       1
# 6             7    15592531        Bartlett          822    France       1
# 7             8    15656148          Obinna          376   Germany       0
# 8             9    15792365              He          501    France       1
# 9            10    15592389              H?          684    France       1
# 10           11    15767821          Bearce          528    France       1
# ...

# %% [markdown]
# # Imbalanced

# %%
print(data['Balance'])
# Out:
# 0        0.0
# 1       10.0
# 2       10.0
# 3        0.0
# 4       10.0
# 5       10.0
# 6        0.0
# 7       10.0
# 8       10.0
# 9       10.0
# 10      10.0
# 11       0.0
# 12       0.0
# 13       0.0
# 14       0.0
# 15      10.0
# 16      10.0
# 17       0.0
# 18       0.0
# 19       0.0
# 20       0.0
# 21       0.0
# 22       0.0
# 23       0.0
# 24       0.0
# 25       0.0
# 26      10.0
# 27       0.0
# 28      10.0
# 29      10.0
#         ...
# 9970    10.0
# 9971    10.0
# 9972    10.0
# 9973     0.0
# 9974    10.0
# 9975    10.0
# 9976    10.0
# 9977     0.0
# 9978    10.0
# 9979    10.0
# 9980    10.0
# 9981    10.0
# 9982    10.0
# 9983     0.0
# 9984    10.0
# 9985    10.0
# 9986    10.0
# 9987    10.0
# 9988     0.0
# 9989     0.0
# 9990    10.0
# 9991    10.0
# 9992     0.0
# 9993    10.0
# 9994     0.0
# 9995     0.0
# 9996    10.0
# 9997     0.0
# 9998    10.0
# 9999    10.0
# Name: Balance, Length: 10000, dtype: float64

# %% [markdown]
# # 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.3, random_state = 0)

# %%
print(x_train)
# Out:
#       RowNumber  CustomerId           Surname  CreditScore Geography  Gender  \
# 7681       7682    15633608             Black          641    France       1
# 9031       9032    15742323            Barese          541    France       1
# 3691       3692    15760244              Ives          590    France       0
# 202         203    15600974                He          516     Spain       1
# 5625       5626    15663234            Bishop          508    France       0
# 298         299    15650068           Johnson          511    France       1
# 5135       5136    15587240          Vasilyev          518    France       1
# 6899       6900    15700263            Ifeatu          569    France       1
# 7258       7259    15747757         Trevascus          600   Germany       0
# 9516       9517    15770567              Ruiz          557    France       0
# 6140       6141    15785042            Hsiung          488    France       0
# ...

# %%
print(x_train.shape)
# Out:
# (7000, 8)

# %%
print(x_test)
# Out:
#       RowNumber  CustomerId       Surname  CreditScore Geography  Gender  Age  \
# 9394       9395    15615753      Upchurch          597   Germany       0   35
# 898         899    15654700       Fallaci          523    France       0   40
# 2398       2399    15633877      Morrison          706     Spain       0   42
# 5906       5907    15745623       Worsnop          788    France       1   32
# 2343       2344    15765902        Gibson          706   Germany       1   38
# 8225       8226    15804142           Tan          670     Spain       0   57
# 5506       5507    15697028     McClinton          590     Spain       1   34
# 6451       6452    15722583      Benjamin          636     Spain       0   29
# 2670       2671    15760446      Pagnotto          598    France       0   64
# 3497       3498    15588944       Maughan          456    France       0   63
# 1087       1088    15696098       Palermo          498    France       0   31
# ...

# %%
print(x_test.shape)
# Out:
# (3000, 8)

# %%
print(y_train)
# Out:
# 7681     55796.83
# 9031     19823.02
# 3691     13848.58
# 202     146145.93
# 5625    129562.74
# 298     162599.51
# 5135    194416.58
# 6899    130784.20
# 7258      6209.51
# 9516     69826.80
# 6140    124210.53
# 9082     17348.56
# 7205     48849.89
# 2819     96875.52
# 5282    108798.36
# 4901     21063.71
# 8449     65316.50
# 9949     44351.77
# 5466    159403.68
# 4503     37136.15
# 210     169381.90
# 7658     88479.02
# 5964     76870.81
# 3650    141023.01
# 5624    143298.06
# 8728     56784.11
# 4919    102260.16
# 2345     23596.24
# 4162       937.15
# 1153    143619.52
#           ...
# 755     141300.53
# 8291     69370.05
# 2496    121053.19
# 7599    120892.96
# 1871     15887.68
# 2046       343.38
# 7877    188426.13
# 4851     85081.09
# 5072    181224.56
# 2163     45206.57
# 6036     50743.83
# 6921      6075.36
# 6216     95270.83
# 537     127569.80
# 9893    124095.69
# 2897     49284.00
# 7768     86791.90
# 2222    175423.69
# 2599     64490.67
# ...

# %%
print(y_test)
# Out:
# 9394    192852.67
# 898     128702.10
# 2398     75732.25
# 5906     89368.59
# 2343    135662.17
# 8225     99061.75
# 5506    160346.30
# 6451    101102.39
# 2670     13181.37
# 3497    140758.07
# 1087     13892.57
# 1819    139889.15
# 2308    123613.81
# 6084    108675.01
# 3724     46675.51
# 3184    137674.96
# 6387    152499.80
# 3728    131970.86
# 2702    196894.62
# 7883     51143.43
# 2930     19862.78
# 5988     56991.66
# 4890    140286.69
# 6718    112668.06
# 5423     68730.91
# 3213     13460.27
# 3017    122487.73
# 382     146700.22
# 4237    190035.83
# 4721    137136.29
#           ...
# 5325     78463.99
# 2636    145537.32
# 8971    124874.23
# 6897     92144.09
# 8936     52035.29
# 6649    189310.27
# 5494    137702.01
# 9967    158590.25
# 263     111879.21
# 7825     56756.52
# 7368    174235.06
# 8995     77660.03
# 2131    105140.92
# 2285     47775.34
# 9441    108764.69
# 4060     44904.26
# 8312     57962.41
# 3263     33879.26
# 9545    195940.96
# ...
